# %%
import dask.dataframe as dd
import dask.bag as db
import pandas as pd
import json
import glob

# %%
# Set datapaths

dicepath = '/Users/daniellee/Jupyter/utils/test_data/dice/05'
hapath = '/Users/daniellee/Jupyter/utils/test_data/home_advisor'
drspath = '/Users/daniellee/Data/device_risk_score/data_v1/raw/raw.csv'

# %%
import pandas as pd
import numpy as np
from glob import glob
    
class CSVCreateConfig:
    
    def __init__(self, path):
        """
        :param path:
        :parm nrows:
        
        """ 
        
        from glob import glob
        
        self.path = path
        
        self.multiplefiles = False
        filepath = glob(path)
        
        if len(filepath) > 1: 
            print('Multiple files detected...')
            self.multiplefiles = True
            
    def infer_dt(self, column, dtype):
        
        if dtype in ['int','float']:
            return False
        
        size = column.shape[0]
        sample_size = int(size * 0.05)
        sampled_rows = column.sample(sample_size, replace=False)
        
        total = 0
        
        for v in sampled_rows.values:
            if isinstance(v, (float, int)):
                v = str(v)
            
            if column.dtype == 'object':
                total += 1
            if '-' in v or ':' in v:
                total += 1
            if len(v) < 30:
                total += 1
            if len(v.split('.')) > 1:
                total += 1
            if len(v.split('-')) == 3:
                total += 1
            if len(v.split(':')) == 3:
                total += 1
                
        if total / (sample_size * 6) > 0.5:
            return True
        return False
    

    def infer_special_case(self, column, name, nunique, dtype):
        
        if dtype in ['int','float']:
            return False
        
        size = column.shape[0]
        sample_size = int(size * 0.05)
        sampled_rows = column.sample(sample_size, replace=False)
        
        total = 0
        for v in sampled_rows.values:
            if column.dtype == 'object':
                total += 1
            if isinstance(v, (list, dict)):
                total += 1
            if nunique > 500:
                total += 1
            if len(str(v)) > 30:
                total += 1
        
        if total / (sample_size * 4) > 0.5:
            return True
        return False
    
    def infer_cat(self, column, name, nunique):
        
        size = column.shape[0]
        sample_size = int(size * 0.05)
        sampled_rows = column.sample(sample_size, replace=False)
        
        total = 0
        for v in sampled_rows.values:
            if isinstance(v, int) or isinstance(v, float):
                v = str(v)
            if column.dtype == 'object':
                total += 1
            if isinstance(v, (str)):
                total += 1
            if nunique < 500:
                total += 1
            if len(str(v)) < 5:
                total += 1
        
        if total / (sample_size * 4) > 0.5:
            return True
        return False
    
    def infer_cont(self, column, name, nunique):
        
        size = column.shape[0]
        sample_size = int(size * 0.05)
        sampled_rows = column.sample(sample_size, replace=False)
        
        total = 0
        for v in sampled_rows.values:
            if column.dtype == 'int' or column.dtype == 'float':
                total += 1
            if nunique > 500:
                total += 1
            if any(x in name for x in ['max','min','avg','mean','average','count','sum','total','computation_time']):
                total += 1
            if  len(str(v)) < 15:
                total += 1
        
        if total / (sample_size * 4) > 0.5:
            return True
        return False
            
    def assign_impute_vartype(self, data, **params):
        """
        :param opath: 
        :param nrows: 
        
        :return:  
        """
        
        impute_dict = dict()
        for c in params['columns']:
            nunique = params['nunique'][c]
            dtype = params['dtypes'][c]
            null  = params['nulls'][c]
            
            if nunique == 1:
                impute_dict[c] = 'single_value'
            elif nunique == 2 or (nunique == 3 and null):
                impute_dict[c] = 'binary'
            elif dtype == 'datetime64[ns]' or dtype == 'Timestamp':
                impute_dict[c] = 'datetime'
            elif self.infer_dt(data[c], dtype):
                impute_dict[c] = 'datetime'
            elif nunique >= 3 and self.infer_special_case(data[c], c, nunique, dtype):
                impute_dict[c] = 'unknown'
            elif nunique >= 3 and self.infer_cat(data[c], c, nunique):
                impute_dict[c] = 'categorical'
            elif nunique >= 3 and self.infer_cont(data[c], c, nunique): 
                impute_dict[c] = 'continuous'
            else:
                impute_dict[c] = 'unknown'
            
        return impute_dict
    
    def single_file_process(self, path, skipids):
        """
        :param path:
        :param skipids:

        :return:  
        """
        
        sample = pd.read_csv(path, skiprows=skipids, low_memory=False)
        columns = sample.columns
        dtypes = sample.dtypes.to_dict()
        nulls = sample.isnull().any().to_dict()
        nunique = {k:(v + 1 if nulls[k] else v) 
                    for k, v in sample.nunique().items()}
        itypes = self.assign_impute_vartype(sample, 
                                            columns = columns,
                                            dtypes = dtypes,
                                            nulls = nulls,
                                            nunique = nunique)
    
        return [columns, itypes, dtypes, nulls]
                
    def generate(self, opath='', prows=0.10, id_vars=[]):
        """
        :param opath: 
        :param prows: 
        
        :return:  
        """
        
        filesize = len([1 for l in open(self.path)])
        rows_to_skip = np.random.choice(range(1,filesize), 
                                      size=int(filesize * (1-prows)), 
                                      replace=False)
        
        
        cols, itypes, dtypes, nulls = self.single_file_process(self.path, rows_to_skip)

        output = list()
        for c in cols:
            itype = itypes[c]
            dtype = dtypes[c]
            null = nulls[c]
            
            if c in id_vars:
                dtype = '_id'
            if itype in ['categorical']:
                dtype = 'category'
            
            output.append({'field': c, 
                           'imputetype': itype, 
                           'dtype': dtype,
                           'null': null})
        
        return output
             
"""
[
{'column': 'name', 'null': True, 'dtype': <dtype>, 'imputetype': <imputetype>}
]
"""

cc = CSVCreateConfig('/Users/daniellee/Data/device_risk_score/data_v1/raw/raw.csv')
tempoutput=cc.generate('/Users/daniellee/Jupyter/utils/test_data/drs_Config.json')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-431-aa63c23918c8> in <module>()
#     220
#     221 cc = CSVCreateConfig('/Users/daniellee/Data/device_risk_score/data_v1/raw/raw.csv')
# --> 222 tempoutput=cc.generate('/Users/daniellee/Jupyter/utils/test_data/drs_Config.json')
#
# <ipython-input-431-aa63c23918c8> in generate(self, opath, prows, id_vars)
#     193
#     194
# --> 195         cols, itypes, dtypes, nulls = self.single_file_process(self.path, rows_to_skip)
#     196
#     197         output = list()
#
# <ipython-input-431-aa63c23918c8> in single_file_process(self, path, skipids)
#     175                                             dtypes = dtypes,
#     176                                             nulls = nulls,
# --> 177                                             nunique = nunique)
#     178
#     179         return [columns, itypes, dtypes, nulls]
#
# <ipython-input-431-aa63c23918c8> in assign_impute_vartype(self, data, **params)
#     142             elif nunique == 2 or (nunique == 3 and null):
#     143                 impute_dict[c] = 'binary'
# --> 144             elif dtype == 'datetime64[ns]' or dtype == 'Timestamp':
#     145                 impute_dict[c] = 'datetime'
#     146             elif self.infer_dt(data[c], dtype):
#
# TypeError: data type "Timestamp" not understood

# %%
tempoutput
# Out:
# [{'dtype': dtype('O'),
#   'field': '__time',
#   'imputetype': 'datetime',
#   'null': False},
#  {'dtype': dtype('float64'),
#   'field': 'android_accelerometer_data',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_accelerometer_name',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_accelerometer_power',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_accelerometer_vendor',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_accelerometer_version',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_application_signature_set',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_available_browser_packages',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_available_call_packages',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_available_external_storage',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_available_input_method_packages',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'android_available_internal_storage',
#   'imputetype': 'continuous',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_available_launcher_packages',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'android_available_ram',
#   'imputetype': 'continuous',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_available_sms_packages',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_battery_charging_type',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_battery_percentage',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_battery_technology',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_battery_temperature',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'android_battery_voltage',
#   'imputetype': 'continuous',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'android_bluetooth_adapter_hardware_address',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'android_bluetooth_adapter_name',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'android_bluetooth_adapter_state',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_build_board',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_build_bootloader',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_build_brand',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_build_device',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_build_display',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_build_hardware',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_build_host',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_build_id',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_build_manufacturer',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_build_model',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_build_product',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_build_radio',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_build_serial',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_build_supported_abis',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_build_tags',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'android_build_time',
#   'imputetype': 'continuous',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'android_build_type',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'android_build_version_code_name',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_build_version_sdk',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'android_call_end_button_behavior',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'android_cellular_data_state',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_cellular_network_subtype',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_configured_accounts',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'android_configured_wifi_networks',
#   'imputetype': 'unknown',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_connection_type',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_cpu_info',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_cpu_max_frequency',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_cpu_min_frequency',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_cpu_num_of_cores',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'android_cpu_usage',
#   'imputetype': 'continuous',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_current_input_method_language',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'android_current_screen_display_id',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_date_format',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_default_alarm_tone',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_default_browser_package',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_default_call_package',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_default_font_size_in_pixels',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_default_input_method_package',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_default_launcher_package',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_default_notification_tone',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_default_ringtone',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_default_sms_package',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'android_device_up_time_in_minutes',
#   'imputetype': 'continuous',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'android_facebook_attribution_id',
#   'imputetype': 'unknown',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_font_scale',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'android_gps_last_known_location',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_gsf_id',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'android_gyroscope_data',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_gyroscope_name',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_gyroscope_power',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_gyroscope_vendor',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_gyroscope_version',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_host_app_version',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'android_http_proxy',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_id',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_imei_no',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_imsi_no',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_installed_widgets_count',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_installed_widgets_hash',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_installer_package_name',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'android_is_24_hour_clock_format_enabled',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'android_is_active_network_connected',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'android_is_adb_enabled',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'android_is_airplane_mode_enabled',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'android_is_application_debuggable',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'android_is_auto_rotation_enabled',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'android_is_auto_time_update_enabled',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'android_is_auto_time_zone_update_enabled',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'android_is_battery_charging',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'android_is_bluetooth_enabled',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'android_is_developement_setting_enabled',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'android_is_device_provisioned',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'android_is_device_rooted',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'android_is_dialpad_tone_enabled',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'android_is_emulator',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'android_is_external_storage_mounted',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'android_is_gps_location_enabled',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'android_is_haptic_feedback_enabled',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'android_is_in_roaming_area',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'android_is_live_wallpaper_set',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'android_is_lock_pattern_enabled',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'android_is_lock_pattern_visible',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'android_is_low_memory',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'android_is_network_location_enabled',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'android_is_non_market_app_installation_enabled',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'android_is_screen_brightness_auto_mode_enabled',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'android_is_sound_effects_enabled',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'android_is_stay_on_while_plugged_in_enabled',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'android_is_text_auto_caps_enabled',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'android_is_text_auto_punctuation_enabled',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'android_is_text_auto_replace_enabled',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'android_is_text_show_password_enabled',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'android_is_vibrate_enabled',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'android_is_wifi_enabled',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_live_wallpaper_package',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_mac_address',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_network_country_iso',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_network_operator_name',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_next_alarm_creator_package',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_next_alarm_trigger_time',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_os_arch',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'android_os_kernel_name',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_phone_no',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_phone_type',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_ringer_mode',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_screen_brightness',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_screen_density',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_screen_density_dpi',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_screen_density_x',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_screen_density_y',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_screen_off_timeout',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_screen_refresh_rate',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_screen_resolution',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'android_screen_rotation',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_screen_size',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': dtype('int64'),
#   'field': 'android_sensor_computation_time_sum',
#   'imputetype': 'single_value',
#   'null': False},
#  {'dtype': 'category',
#   'field': 'android_signal_source_app',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_sim_country_iso',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_sim_operator_name',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_sim_serial_no',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_sim_state',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_system_installed_apps_count',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_system_installed_apps_hash',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_time_zone_offset',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_total_external_storage',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_total_internal_storage',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_total_ram',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_tts_default_engine_name',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_tts_default_pitch',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_tts_default_rate',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_user_installed_apps_count',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'android_user_installed_apps_hash',
#   'imputetype': 'unknown',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_wifi_link_speed',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'android_wifi_signal_strength',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'android_wifi_ssid_name',
#   'imputetype': 'unknown',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'beacon_client_type',
#   'imputetype': 'categorical',
#   'null': False},
#  {'dtype': 'category',
#   'field': 'beacon_client_version',
#   'imputetype': 'categorical',
#   'null': False},
#  {'dtype': dtype('int64'),
#   'field': 'beacon_request_type',
#   'imputetype': 'single_value',
#   'null': False},
#  {'dtype': dtype('float64'),
#   'field': 'browser_app_name',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'browser_canvas_fingerprint',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'browser_cookie_enabled',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_do_not_track',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'browser_document_referrer',
#   'imputetype': 'unknown',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_flash_av_hardware_disable',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_flash_cpu_architecture',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_flash_done',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_flash_error',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_flash_exact_settings',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_flash_fonts_hash',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_flash_has_accessibility',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_flash_has_audio',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_flash_has_audio_encoder',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_flash_has_embedded_video',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_flash_has_ime',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_flash_has_mp3',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_flash_has_printing',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_flash_has_screen_broadcast',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_flash_has_screen_playback',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_flash_has_streaming_audio',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_flash_has_streaming_video',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_flash_has_tls',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_flash_has_video_encoder',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_flash_is_debugger',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_flash_is_embedded_in_acrobat',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_flash_language',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_flash_local_file_read_disable',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_flash_manufacturer',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_flash_max_level_idc',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_flash_os',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_flash_pixel_aspect_ratio',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_flash_player_type',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_flash_sandbox_type',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_flash_screen_color',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_flash_screen_dpi',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_flash_screen_resolution',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_flash_server_string',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_flash_supports_32_bit_processes',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_flash_supports_64_bit_processes',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_flash_supports_dolby_digital_audio',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_flash_supports_dolby_digital_plus_audio',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_flash_supports_dts_audio',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_flash_supports_dts_express_audio',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_flash_supports_dtshd_high_reolution_audio',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_flash_supports_dtshd_master_audio',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_flash_touch_screen_type',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_flash_version',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_hardware_concurrency',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'browser_history_length',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_image_enabled',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'browser_js_disabled',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'browser_language',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'browser_languages',
#   'imputetype': 'datetime',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_local_time',
#   'imputetype': 'continuous',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_location_done',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_location_error',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'browser_max_touch_points',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'browser_mime_types',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_mouse_movements',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'browser_num_mime_types',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'browser_num_plugins',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_on_line',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'browser_platform',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'browser_plugins_json',
#   'imputetype': 'unknown',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_private_mode_enabled',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_product',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_product_sub',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_screen_available_height',
#   'imputetype': 'continuous',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'browser_screen_available_width',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'browser_screen_color_depth',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'browser_screen_height',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'browser_screen_pixel_depth',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'browser_screen_width',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_screen_x',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_screen_y',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_supported_fonts_hash',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_supported_input_attributes',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_supported_input_types',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_supports_application_cache',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_supports_audio',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_supports_canvas',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_supports_canvas_text',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_supports_history',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_supports_indexed_db',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_supports_local_storage',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'browser_supports_open_database',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_supports_post_message',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_supports_session_storage',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_supports_video',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'browser_supports_web_gl',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_supports_web_socket',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_supports_web_worker',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'browser_timezone_offset',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'browser_tor_enabled',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'browser_user_agent',
#   'imputetype': 'unknown',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'browser_vendor',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_web_gl_alpha_bits',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_web_gl_blue_bits',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_web_gl_depth_bits',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'browser_web_gl_fingerprint',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_web_gl_fragment_shader_float_precision',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_web_gl_fragment_shader_int_precision',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_web_gl_green_bits',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_web_gl_max_anisotropy',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_web_gl_max_combined_texture_image_units',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_web_gl_max_cube_map_texture_size',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_web_gl_max_fragment_uniform_vectors',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_web_gl_max_render_buffer_size',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_web_gl_max_texture_image_units',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_web_gl_max_texture_size',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_web_gl_max_varying_vectors',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_web_gl_max_vertex_attributes',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_web_gl_max_vertex_texture_image_units',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_web_gl_max_vertex_uniform_vectors',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_web_gl_red_bits',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'browser_web_gl_renderer',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_web_gl_shading_language_version',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_web_gl_stencil_bits',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_web_gl_supported_extensions_hash',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'browser_web_gl_supported_gl_contexts',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'browser_web_gl_supports_antialias',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'browser_web_gl_vendor',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'browser_web_gl_version',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('int64'),
#   'field': 'computation_try_count',
#   'imputetype': 'continuous',
#   'null': False},
#  {'dtype': dtype('int64'),
#   'field': 'count',
#   'imputetype': 'binary',
#   'null': False},
#  {'dtype': 'category',
#   'field': 'customer_app_prefix',
#   'imputetype': 'categorical',
#   'null': False},
#  {'dtype': 'category',
#   'field': 'customer_event_types',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'customer_id',
#   'imputetype': 'categorical',
#   'null': False},
#  {'dtype': dtype('O'),
#   'field': 'customer_session_id',
#   'imputetype': 'unknown',
#   'null': False},
#  {'dtype': dtype('O'),
#   'field': 'customer_transaction_data',
#   'imputetype': 'unknown',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'customer_user_id',
#   'imputetype': 'unknown',
#   'null': True},
#  {'dtype': dtype('int64'),
#   'field': 'device_first_seen_timestamp',
#   'imputetype': 'continuous',
#   'null': False},
#  {'dtype': dtype('O'),
#   'field': 'device_id',
#   'imputetype': 'unknown',
#   'null': False},
#  {'dtype': dtype('O'),
#   'field': 'device_id_computation_errors',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('int64'),
#   'field': 'device_id_computation_time_sum',
#   'imputetype': 'continuous',
#   'null': False},
#  {'dtype': dtype('O'),
#   'field': 'device_ids',
#   'imputetype': 'unknown',
#   'null': False},
#  {'dtype': 'category',
#   'field': 'device_ids_browser_version',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'device_ids_canvas_fingerprint',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'device_ids_common_signals',
#   'imputetype': 'unknown',
#   'null': False},
#  {'dtype': dtype('O'),
#   'field': 'device_ids_device_id',
#   'imputetype': 'unknown',
#   'null': False},
#  {'dtype': dtype('O'),
#   'field': 'device_ids_flash_signals',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'device_ids_os_version',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'device_ids_web_gl_fingerprint',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'device_last_seen_latitude',
#   'imputetype': 'continuous',
#   'null': False},
#  {'dtype': dtype('float64'),
#   'field': 'device_last_seen_longitude',
#   'imputetype': 'continuous',
#   'null': False},
#  {'dtype': dtype('int64'),
#   'field': 'device_last_seen_timestamp',
#   'imputetype': 'continuous',
#   'null': False},
#  {'dtype': 'category',
#   'field': 'device_match_reason',
#   'imputetype': 'categorical',
#   'null': False},
#  {'dtype': dtype('O'),
#   'field': 'device_match_result',
#   'imputetype': 'binary',
#   'null': False},
#  {'dtype': dtype('int64'),
#   'field': 'device_ml_score_computation_time_sum',
#   'imputetype': 'single_value',
#   'null': False},
#  {'dtype': dtype('int64'),
#   'field': 'device_neighbors_computation_time_sum',
#   'imputetype': 'single_value',
#   'null': False},
#  {'dtype': 'category',
#   'field': 'device_sensor_computation_time',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'device_unified_joiner',
#   'imputetype': 'unknown',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'devicereconandroidemulatordevice_computation_time',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'devicereconandroidrooteddevice_computation_time',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'devicereconandroidtimezonemismatch_computation_errors',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'devicereconandroidtimezonemismatch_computation_time',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'devicereconbrowsercookiedisabled_computation_errors',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'devicereconbrowsercookiedisabled_computation_time',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'devicereconbrowserimagedisabled_computation_errors',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'devicereconbrowserimagedisabled_computation_time',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'devicereconbrowserjsdisabled_computation_errors',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'devicereconbrowserjsdisabled_computation_time',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'devicereconbrowserlanguageflashlanguagemismatch_computation_errors',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'devicereconbrowserlanguageflashlanguagemismatch_computation_time',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'devicereconbrowserprivatemode_computation_errors',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'devicereconbrowserprivatemode_computation_time',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'devicereconbrowseruseragentmismatch_computation_errors',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'devicereconbrowseruseragentmismatch_computation_time',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'devicerecondeviceblacklisted_computation_errors',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('int64'),
#   'field': 'devicerecondeviceblacklisted_computation_time',
#   'imputetype': 'unknown',
#   'null': False},
#  {'dtype': dtype('float64'),
#   'field': 'devicerecondevicespoofing_computation_errors',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'devicerecondevicespoofing_computation_time',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'devicerecondevicewhitelisted_computation_errors',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('int64'),
#   'field': 'devicerecondevicewhitelisted_computation_time',
#   'imputetype': 'unknown',
#   'null': False},
#  {'dtype': dtype('int64'),
#   'field': 'devicereconempty_computation_time',
#   'imputetype': 'unknown',
#   'null': False},
#  {'dtype': dtype('O'),
#   'field': 'devicerecongeolocationmismatch_computation_errors',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('int64'),
#   'field': 'devicerecongeolocationmismatch_computation_time',
#   'imputetype': 'unknown',
#   'null': False},
#  {'dtype': dtype('O'),
#   'field': 'devicereconidentityspoofing_computation_errors',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'devicereconidentityspoofing_computation_time',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'devicereconipblacklisted_computation_errors',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('int64'),
#   'field': 'devicereconipblacklisted_computation_time',
#   'imputetype': 'unknown',
#   'null': False},
#  {'dtype': dtype('O'),
#   'field': 'devicereconipblocklist_computation_errors',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('int64'),
#   'field': 'devicereconipblocklist_computation_time',
#   'imputetype': 'unknown',
#   'null': False},
#  {'dtype': dtype('float64'),
#   'field': 'devicereconipinglobalthreatlist_computation_errors',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('int64'),
#   'field': 'devicereconipinglobalthreatlist_computation_time',
#   'imputetype': 'unknown',
#   'null': False},
#  {'dtype': dtype('float64'),
#   'field': 'devicereconipisanonymizingvpnservice_computation_errors',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('int64'),
#   'field': 'devicereconipisanonymizingvpnservice_computation_time',
#   'imputetype': 'unknown',
#   'null': False},
#  {'dtype': dtype('O'),
#   'field': 'devicereconipisanonymousproxy_computation_errors',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('int64'),
#   'field': 'devicereconipisanonymousproxy_computation_time',
#   'imputetype': 'unknown',
#   'null': False},
#  {'dtype': dtype('O'),
#   'field': 'devicereconipisdshield_computation_errors',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('int64'),
#   'field': 'devicereconipisdshield_computation_time',
#   'imputetype': 'unknown',
#   'null': False},
#  {'dtype': dtype('O'),
#   'field': 'devicereconipisexploitbot_computation_errors',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('int64'),
#   'field': 'devicereconipisexploitbot_computation_time',
#   'imputetype': 'unknown',
#   'null': False},
#  {'dtype': dtype('O'),
#   'field': 'devicereconipishijacked_computation_errors',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('int64'),
#   'field': 'devicereconipishijacked_computation_time',
#   'imputetype': 'unknown',
#   'null': False},
#  {'dtype': dtype('O'),
#   'field': 'devicereconipismalware_computation_errors',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('int64'),
#   'field': 'devicereconipismalware_computation_time',
#   'imputetype': 'unknown',
#   'null': False},
#  {'dtype': dtype('O'),
#   'field': 'devicereconipisproxy_computation_errors',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('int64'),
#   'field': 'devicereconipisproxy_computation_time',
#   'imputetype': 'unknown',
#   'null': False},
#  {'dtype': dtype('float64'),
#   'field': 'devicereconipispubliccgiproxy_computation_errors',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('int64'),
#   'field': 'devicereconipispubliccgiproxy_computation_time',
#   'imputetype': 'unknown',
#   'null': False},
#  {'dtype': dtype('O'),
#   'field': 'devicereconipisspambot_computation_errors',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('int64'),
#   'field': 'devicereconipisspambot_computation_time',
#   'imputetype': 'unknown',
#   'null': False},
#  {'dtype': dtype('O'),
#   'field': 'devicereconipisspider_computation_errors',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('int64'),
#   'field': 'devicereconipisspider_computation_time',
#   'imputetype': 'unknown',
#   'null': False},
#  {'dtype': dtype('O'),
#   'field': 'devicereconipisspyware_computation_errors',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('int64'),
#   'field': 'devicereconipisspyware_computation_time',
#   'imputetype': 'unknown',
#   'null': False},
#  {'dtype': dtype('O'),
#   'field': 'devicereconipistornode_computation_errors',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('int64'),
#   'field': 'devicereconipistornode_computation_time',
#   'imputetype': 'unknown',
#   'null': False},
#  {'dtype': dtype('O'),
#   'field': 'devicereconipisvpn_computation_errors',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('int64'),
#   'field': 'devicereconipisvpn_computation_time',
#   'imputetype': 'unknown',
#   'null': False},
#  {'dtype': dtype('float64'),
#   'field': 'devicereconipspoofing_computation_errors',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('int64'),
#   'field': 'devicereconipspoofing_computation_time',
#   'imputetype': 'unknown',
#   'null': False},
#  {'dtype': dtype('O'),
#   'field': 'devicereconipwhitelisted_computation_errors',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('int64'),
#   'field': 'devicereconipwhitelisted_computation_time',
#   'imputetype': 'unknown',
#   'null': False},
#  {'dtype': dtype('O'),
#   'field': 'devicereconnetworkcountryipcountryisomismatch_computation_errors',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'devicereconnetworkcountryipcountryisomismatch_computation_time',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'devicereconpotentialmalware_computation_errors',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('int64'),
#   'field': 'devicereconpotentialmalware_computation_time',
#   'imputetype': 'unknown',
#   'null': False},
#  {'dtype': dtype('O'),
#   'field': 'devicerecontimezonemismatch_computation_errors',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'devicerecontimezonemismatch_computation_time',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'devicerecontrueipblacklisted_computation_errors',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'devicerecontrueipblacklisted_computation_time',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'devicerecontrueipblocklist_computation_errors',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'devicerecontrueipblocklist_computation_time',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'devicerecontrueipinglobalthreatlist_computation_errors',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('int64'),
#   'field': 'devicerecontrueipinglobalthreatlist_computation_time',
#   'imputetype': 'unknown',
#   'null': False},
#  {'dtype': dtype('float64'),
#   'field': 'devicerecontrueipisanonymizingvpnservice_computation_errors',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'devicerecontrueipisanonymizingvpnservice_computation_time',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'devicerecontrueipisanonymousproxy_computation_errors',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'devicerecontrueipisanonymousproxy_computation_time',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'devicerecontrueipisdshield_computation_errors',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'devicerecontrueipisdshield_computation_time',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'devicerecontrueipisexploitbot_computation_errors',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'devicerecontrueipisexploitbot_computation_time',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'devicerecontrueipishijacked_computation_errors',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'devicerecontrueipishijacked_computation_time',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'devicerecontrueipismalware_computation_errors',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'devicerecontrueipismalware_computation_time',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'devicerecontrueipisproxy_computation_errors',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'devicerecontrueipisproxy_computation_time',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'devicerecontrueipispubliccgiproxy_computation_errors',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'devicerecontrueipispubliccgiproxy_computation_time',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'devicerecontrueipisspambot_computation_errors',
#   'imputetype': 'binary',
#   'null': True},
# ...
#   'null': True},
#  {'dtype': 'category',
#   'field': 'ios_network_carrier_mobile_country_code',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'ios_network_carrier_mobile_network_code',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'ios_network_carrier_name',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'ios_proximity_state',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'ios_system_name',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'ios_system_version',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'ios_user_interface_idiom',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'ios_wants_software_dimming',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('int64'),
#   'field': 'ip_accuracy_radius',
#   'imputetype': 'unknown',
#   'null': False},
#  {'dtype': dtype('O'),
#   'field': 'ip_address',
#   'imputetype': 'unknown',
#   'null': False},
#  {'dtype': dtype('int64'),
#   'field': 'ip_autonomous_system_number',
#   'imputetype': 'continuous',
#   'null': False},
#  {'dtype': dtype('O'),
#   'field': 'ip_autonomous_system_organization',
#   'imputetype': 'unknown',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'ip_city_name',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'ip_connection_type',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'ip_continent_name',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'ip_country_iso_code',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'ip_country_name',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'ip_domain',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'ip_geo_computation_errors',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': dtype('int64'),
#   'field': 'ip_geo_computation_time_sum',
#   'imputetype': 'continuous',
#   'null': False},
#  {'dtype': dtype('int64'),
#   'field': 'ip_geo_neutrino_computation_time_sum',
#   'imputetype': 'continuous',
#   'null': False},
#  {'dtype': dtype('bool'),
#   'field': 'ip_is_anonymous_proxy',
#   'imputetype': 'single_value',
#   'null': False},
#  {'dtype': dtype('O'),
#   'field': 'ip_is_dshield',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'ip_is_exploit_bot',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'ip_is_hijacked',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'ip_is_malware',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'ip_is_proxy',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('bool'),
#   'field': 'ip_is_satellite_provider',
#   'imputetype': 'single_value',
#   'null': False},
#  {'dtype': dtype('O'),
#   'field': 'ip_is_spam_bot',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'ip_is_spider',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'ip_is_spyware',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'ip_is_tor_node',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'ip_is_vpn',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'ip_isp',
#   'imputetype': 'unknown',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'ip_latitutde',
#   'imputetype': 'continuous',
#   'null': False},
#  {'dtype': dtype('float64'),
#   'field': 'ip_longitude',
#   'imputetype': 'continuous',
#   'null': False},
#  {'dtype': dtype('O'),
#   'field': 'ip_organization',
#   'imputetype': 'unknown',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'ip_postal_code',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'ip_registered_country_iso_code',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'ip_registered_country_name',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'ip_represented_country_code',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'ip_represented_country_name',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'ip_represented_country_type',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'ip_score_neutrino_computation_errors',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'ip_subdivision_name',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'ip_time_zone',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'is_ipv6',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'is_true_ipv6',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'local_ip_address',
#   'imputetype': 'unknown',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'mouse_movement_computation_time',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'only_lite_signals',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'parse_json_computation_errors',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('int64'),
#   'field': 'parse_json_computation_time_sum',
#   'imputetype': 'continuous',
#   'null': False},
#  {'dtype': dtype('float64'),
#   'field': 'plugins_computation_errors',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('int64'),
#   'field': 'plugins_computation_time_sum',
#   'imputetype': 'continuous',
#   'null': False},
#  {'dtype': dtype('O'),
#   'field': 'referer',
#   'imputetype': 'datetime',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'remote_ip_address',
#   'imputetype': 'datetime',
#   'null': False},
#  {'dtype': dtype('int64'),
#   'field': 'rule_android_emulator_device_computation_time_sum',
#   'imputetype': 'single_value',
#   'null': False},
#  {'dtype': dtype('int64'),
#   'field': 'rule_android_rooted_device_computation_time_sum',
#   'imputetype': 'single_value',
#   'null': False},
#  {'dtype': dtype('int64'),
#   'field': 'rule_android_timezone_mismatch_computation_time_sum',
#   'imputetype': 'single_value',
#   'null': False},
#  {'dtype': dtype('int64'),
#   'field': 'rule_browser_language_flash_language_mismatch_computation_time_sum',
#   'imputetype': 'single_value',
#   'null': False},
#  {'dtype': dtype('int64'),
#   'field': 'rule_browser_private_mode_computation_time_sum',
#   'imputetype': 'single_value',
#   'null': False},
#  {'dtype': dtype('int64'),
#   'field': 'rule_geo_location_mismatch_computation_time_sum',
#   'imputetype': 'single_value',
#   'null': False},
#  {'dtype': dtype('int64'),
#   'field': 'rule_ip_is_dshield_computation_time_sum',
#   'imputetype': 'single_value',
#   'null': False},
#  {'dtype': dtype('int64'),
#   'field': 'rule_ip_is_exploit_bot_computation_time_sum',
#   'imputetype': 'single_value',
#   'null': False},
#  {'dtype': dtype('int64'),
#   'field': 'rule_ip_is_hijacked_computation_time_sum',
#   'imputetype': 'single_value',
#   'null': False},
#  {'dtype': dtype('int64'),
#   'field': 'rule_ip_is_malware_computation_time_sum',
#   'imputetype': 'single_value',
#   'null': False},
#  {'dtype': dtype('int64'),
#   'field': 'rule_ip_is_proxy_computation_time_sum',
#   'imputetype': 'single_value',
#   'null': False},
#  {'dtype': dtype('int64'),
#   'field': 'rule_ip_is_spam_bot_computation_time_sum',
#   'imputetype': 'single_value',
#   'null': False},
#  {'dtype': dtype('int64'),
#   'field': 'rule_ip_is_spider_computation_time_sum',
#   'imputetype': 'single_value',
#   'null': False},
#  {'dtype': dtype('int64'),
#   'field': 'rule_ip_is_spyware_computation_time_sum',
#   'imputetype': 'single_value',
#   'null': False},
#  {'dtype': dtype('int64'),
#   'field': 'rule_ip_is_tor_node_computation_time_sum',
#   'imputetype': 'single_value',
#   'null': False},
#  {'dtype': dtype('int64'),
#   'field': 'rule_ip_is_vpn_computation_time_sum',
#   'imputetype': 'single_value',
#   'null': False},
#  {'dtype': dtype('int64'),
#   'field': 'rule_ip_mismatch_computation_time_sum',
#   'imputetype': 'single_value',
#   'null': False},
#  {'dtype': dtype('int64'),
#   'field': 'rule_ip_true_ip_city_mismatch_computation_time_sum',
#   'imputetype': 'single_value',
#   'null': False},
#  {'dtype': dtype('int64'),
#   'field': 'rule_ip_true_ip_country_mismatch_computation_time_sum',
#   'imputetype': 'single_value',
#   'null': False},
#  {'dtype': dtype('int64'),
#   'field': 'rule_ip_true_ip_isp_mismatch_computation_time_sum',
#   'imputetype': 'single_value',
#   'null': False},
#  {'dtype': dtype('int64'),
#   'field': 'rule_ip_true_ip_organization_mismatch_computation_time_sum',
#   'imputetype': 'single_value',
#   'null': False},
#  {'dtype': dtype('int64'),
#   'field': 'rule_ip_true_ip_timezone_mismatch_computation_time_sum',
#   'imputetype': 'single_value',
#   'null': False},
#  {'dtype': dtype('int64'),
#   'field': 'rule_network_country_ip_country_iso_mismatch_computation_time_sum',
#   'imputetype': 'single_value',
#   'null': False},
#  {'dtype': dtype('int64'),
#   'field': 'rule_timezone_mismatch_computation_time_sum',
#   'imputetype': 'single_value',
#   'null': False},
#  {'dtype': dtype('O'),
#   'field': 'sim_creation_date',
#   'imputetype': 'datetime',
#   'null': False},
#  {'dtype': 'category',
#   'field': 'sim_ll',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': dtype('int64'),
#   'field': 'sim_sc',
#   'imputetype': 'unknown',
#   'null': False},
#  {'dtype': dtype('O'),
#   'field': 'third_party_cookie',
#   'imputetype': 'unknown',
#   'null': False},
#  {'dtype': dtype('O'),
#   'field': 'third_party_session_cookie',
#   'imputetype': 'unknown',
#   'null': False},
#  {'dtype': dtype('float64'),
#   'field': 'total_computation_time_hist',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('int64'),
#   'field': 'total_computation_time_sum',
#   'imputetype': 'continuous',
#   'null': False},
#  {'dtype': 'category',
#   'field': 'true_ip_accuracy_radius',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'true_ip_address',
#   'imputetype': 'unknown',
#   'null': False},
#  {'dtype': dtype('float64'),
#   'field': 'true_ip_autonomous_system_number',
#   'imputetype': 'continuous',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'true_ip_autonomous_system_organization',
#   'imputetype': 'unknown',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'true_ip_city_name',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'true_ip_connection_type',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'true_ip_continent_name',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'true_ip_country_iso_code',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'true_ip_country_name',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'true_ip_domain',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'true_ip_geo_computation_errors',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': dtype('int64'),
#   'field': 'true_ip_geo_computation_time_sum',
#   'imputetype': 'continuous',
#   'null': False},
#  {'dtype': dtype('O'),
#   'field': 'true_ip_is_anonymous_proxy',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'true_ip_is_dshield',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'true_ip_is_exploit_bot',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'true_ip_is_hijacked',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'true_ip_is_malware',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'true_ip_is_proxy',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'true_ip_is_satellite_provider',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'true_ip_is_spam_bot',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'true_ip_is_spider',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'true_ip_is_spyware',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'true_ip_is_tor_node',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'true_ip_is_vpn',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'true_ip_isp',
#   'imputetype': 'unknown',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'true_ip_latitutde',
#   'imputetype': 'continuous',
#   'null': True},
#  {'dtype': dtype('float64'),
#   'field': 'true_ip_longitude',
#   'imputetype': 'continuous',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'true_ip_organization',
#   'imputetype': 'unknown',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'true_ip_postal_code',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'true_ip_registered_country_name',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'true_ip_represented_country_code',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'true_ip_represented_country_name',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'true_ip_represented_country_type',
#   'imputetype': 'binary',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'true_ip_score_neutrino_computation_errors',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': dtype('int64'),
#   'field': 'true_ip_score_neutrino_computation_time_sum',
#   'imputetype': 'continuous',
#   'null': False},
#  {'dtype': 'category',
#   'field': 'true_ip_subdivision_name',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'true_ip_time_zone',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'ua_parse_computation_errors',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': dtype('int64'),
#   'field': 'ua_parse_computation_time_sum',
#   'imputetype': 'continuous',
#   'null': False},
#  {'dtype': dtype('int64'),
#   'field': 'update_device_clusters_computation_time_sum',
#   'imputetype': 'single_value',
#   'null': False},
#  {'dtype': dtype('O'),
#   'field': 'user_agent',
#   'imputetype': 'unknown',
#   'null': False},
#  {'dtype': 'category',
#   'field': 'user_agent_browser_family',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'user_agent_browser_major',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'user_agent_browser_minor',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'user_agent_browser_patch',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'user_agent_device_family',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'user_agent_os_family',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'user_agent_os_patch',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'user_agent_os_vendor',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': 'category',
#   'field': 'user_agent_type',
#   'imputetype': 'categorical',
#   'null': True},
#  {'dtype': dtype('O'),
#   'field': 'user_cookie',
#   'imputetype': 'unknown',
#   'null': False},
#  {'dtype': dtype('float64'),
#   'field': 'user_cookie_computation_errors',
#   'imputetype': 'single_value',
#   'null': True},
#  {'dtype': dtype('int64'),
#   'field': 'user_cookie_computation_time_sum',
#   'imputetype': 'continuous',
#   'null': False},
#  {'dtype': dtype('O'),
#   'field': 'user_session_cookie',
#   'imputetype': 'unknown',
#   'null': True},
#  {'dtype': dtype('int64'),
#   'field': 'flagged',
#   'imputetype': 'binary',
#   'null': False}]

# %%
t4 = pd.read_csv('/Users/daniellee/Data/device_risk_score/data_v1/raw/raw.csv', skiprows=rows_to_skip, low_memory=False)

# %%
testtype = {k['field']:k['dtype'] for k in tempoutput}

# %%
dd.read_csv('/Users/daniellee/Data/device_risk_score/data_v1/raw/raw.csv', dtype=testtype).head()
# Out:
#                      __time  android_accelerometer_data  \
# 0  2018-01-30T23:08:03.781Z                         NaN
# 1  2018-01-31T01:26:29.225Z                         NaN
# 2  2018-01-31T01:27:31.679Z                         NaN
# 3  2018-01-31T13:52:48.269Z                         NaN
# 4  2018-01-31T13:54:10.067Z                         NaN
#
#   android_accelerometer_name android_accelerometer_power  \
# 0                        NaN                         NaN
# 1                        NaN                         NaN
# 2                        NaN                         NaN
# 3                        NaN                         NaN
# 4                        NaN                         NaN
#
#   android_accelerometer_vendor android_accelerometer_version  \
# 0                          NaN                           NaN
# 1                          NaN                           NaN
# 2                          NaN                           NaN
# 3                          NaN                           NaN
# 4                          NaN                           NaN
#
#   android_application_signature_set android_available_browser_packages  \
# 0                               NaN                                NaN
# 1                               NaN                                NaN
# 2                               NaN                                NaN
# 3                               NaN                                NaN
# 4                               NaN                                NaN
#
#   android_available_call_packages android_available_external_storage   ...     \
# 0                             NaN                                NaN   ...
# 1                             NaN                                NaN   ...
# 2                             NaN                                NaN   ...
# 3                             NaN                                NaN   ...
# 4                             NaN                                NaN   ...
#
#   user_agent_device_family  user_agent_os_family user_agent_os_patch  \
# 0        Personal computer             Windows 7                 NaN
# 1        Personal computer             Windows 7                 NaN
# 2        Personal computer             Windows 7                 NaN
# 3        Personal computer             Windows 7                 NaN
# 4        Personal computer             Windows 7                 NaN
#
#      user_agent_os_vendor user_agent_type  \
# 0  Microsoft Corporation.         BROWSER
# 1  Microsoft Corporation.         BROWSER
# 2  Microsoft Corporation.         BROWSER
# 3  Microsoft Corporation.         BROWSER
# 4  Microsoft Corporation.         BROWSER
#
#                             user_cookie user_cookie_computation_errors  \
# 0  356B171B-0270-4BB3-84CD-D0EA4BD5CF11                            NaN
# 1  E0861F0E-AACE-468B-91EF-09F55FD5B407                            NaN
# 2  E0861F0E-AACE-468B-91EF-09F55FD5B407                            NaN
# 3  243FD4D9-4754-409D-87C7-0E4FFB141D4A                            NaN
# 4  243FD4D9-4754-409D-87C7-0E4FFB141D4A                            NaN
#
#   user_cookie_computation_time_sum                   user_session_cookie  \
# 0                                0  1EDBC62F-C2FD-4D09-A212-200DDA01CBE5
# 1                                0  7CE6A8F6-B492-405A-A38D-1EFAF3FCF9CC
# 2                                0  7CE6A8F6-B492-405A-A38D-1EFAF3FCF9CC
# 3                                0  384F795E-A92D-4588-B21B-A279A5A334EC
# 4                                0  384F795E-A92D-4588-B21B-A279A5A334EC
#
#    flagged
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#
# [5 rows x 602 columns]

# %%
import pandas as pd
import numpy as np
from glob import glob
    
class JSONCreateConfig:
    
    def __init__(self, path):
        """
        :param path:
        :parm nrows:
        
        """ 
        
        from glob import glob
        
        self.path = path
        
        self.multiplefiles = False
        self.filepaths = glob(path)
        
    def infer_dt(self, column, dtype):
        
        if dtype in ['int','float']:
            return False
        
        size = column.shape[0]
        sample_size = int(size * 0.05)
        sampled_rows = column.sample(sample_size, replace=False)
        
        total = 0
        
        for v in sampled_rows.values:
            if isinstance(v, int) or isinstance(v, float) or v == None or isinstance(v, list):
                v = str(v)
            if column.dtype == 'object':
                total += 1
            if '-' in v or ':' in v:
                total += 1
            if len(v) < 30:
                total += 1
            if len(v.split('.')) > 1:
                total += 1
            if len(v.split('-')) == 3:
                total += 1
            if len(v.split(':')) == 3:
                total += 1
                
        if total / (sample_size * 6) > 0.5:
            return True
        return False
    
    def infer_special_case(self, column, name, nunique, dtype):
        
        if dtype in ['int','float']:
            return False
        
        size = column.shape[0]
        sample_size = int(size * 0.05)
        sampled_rows = column.sample(sample_size, replace=False)
        
        total = 0
        for v in sampled_rows.values:
            if isinstance(v, int) or isinstance(v, float) or v == None or isinstance(v, list):
                v = str(v)
            if column.dtype == 'object':
                total += 1
            if isinstance(v, (list, dict)):
                total += 1
            if nunique > 500:
                total += 1
            if len(str(v)) > 30:
                total += 1
        
        if total / (sample_size * 4) > 0.5:
            return True
        return False
    
    def infer_cat(self, column, name, nunique):
        
        size = column.shape[0]
        sample_size = int(size * 0.05)
        sampled_rows = column.sample(sample_size, replace=False)
        
        total = 0
        for v in sampled_rows.values:
            if isinstance(v, int) or isinstance(v, float) or v == None or isinstance(v, list):
                v = str(v)
            if column.dtype == 'object':
                total += 1
            if isinstance(v, (str)):
                total += 1
            if nunique < 500:
                total += 1
            if len(str(v)) < 5:
                total += 1
        
        if total / (sample_size * 4) > 0.5:
            return True
        return False
    
    def infer_cont(self, column, name, nunique):
        
        size = column.shape[0]
        sample_size = int(size * 0.05)
        sampled_rows = column.sample(sample_size, replace=False)
        
        total = 0
        for v in sampled_rows.values:
            if isinstance(v, int) or isinstance(v, float) or v == None or isinstance(v, list):
                v = str(v)
            if column.dtype == 'int' or column.dtype == 'float':
                total += 1
            if nunique > 500:
                total += 1
            if any(x in name for x in ['max','min','avg','mean','average','count','sum','total','computation_time']):
                total += 1
            if  len(str(v)) < 15:
                total += 1
        
        if total / (sample_size * 4) > 0.5:
            return True
        return False
    
    def assign_impute_vartype(self, data, **params):
        """
        :param opath: 
        :param nrows: 
        
        :return:  
        """
        
        impute_dict = dict()
        for c in params['columns']:
            nunique = params['nunique'][c]
            dtype = params['dtypes'][c]
            null  = params['nulls'][c]

            if nunique == 1:
                impute_dict[c] = 'single_value'
            elif nunique == 2 or (nunique == 3 and null):
                impute_dict[c] = 'binary'
            elif dtype == 'datetime64[ns]':
                impute_dict[c] = 'datetime'
            elif self.infer_dt(data[c], dtype):
                impute_dict[c] = 'datetime'
            elif nunique >= 3 and self.infer_special_case(data[c], c, nunique, dtype):
                impute_dict[c] = 'unknown'
            elif nunique >= 3 and self.infer_cat(data[c], c, nunique):
                impute_dict[c] = 'categorical'
            elif nunique >= 3 and self.infer_cont(data[c], c, nunique): 
                impute_dict[c] = 'continuous'
            else:
                impute_dict[c] = 'unknown'
            
        return impute_dict
    
    def read_multiple_json(self, paths):
        def read_json(path):
            return pd.read_json(path, lines=True)
        return pd.concat(map(read_json, paths))
    
    def multiple_file_process(self, path):
        """
        :param path:
        :param skipids:

        :return:  
        """
        
        sample = self.read_multiple_json(path)
        columns = sample.columns
        dtypes = sample.dtypes.to_dict()
        nulls = sample.isnull().any().to_dict()
        
        nunique = dict()
        for c in columns:
            try:
                v = sample[c].nunique()
                nunique[c] = v + 1 if nulls[k] else v
            except:
                nunique[c] = sample[c].astype('str').nunique()
        itypes = self.assign_impute_vartype(sample, 
                                            columns = columns,
                                            dtypes = dtypes,
                                            nulls = nulls,
                                            nunique = nunique)
    
        return [columns, itypes, dtypes, nulls]
                
    def generate(self, opath='', pfile=0.2, id_vars=[]):
        """
        :param opath: 
        :param prows: 
        
        :return:  
        """
        
        filecount = len(self.filepaths)
        files_to_select = np.random.choice(self.filepaths, 
                                      size=int(filecount * (pfile)), 
                                      replace=False)
        cols, itypes, dtypes, nulls = self.multiple_file_process(files_to_select)

        output = list()
        for c in cols:
            itype = itypes[c]
            dtype = dtypes[c]
            null = nulls[c]
            
            if c in id_vars:
                dtype = '_id'
            if itype in ['categorical']:
                dtype = 'category'
            
            output.append({'field': c, 
                           'imputetype': itype, 
                           'dtype': str(dtype),
                           'null': null})
            
        setting = {
            "setting": {
                "continuous": [],
                "categorical": [],
                "binary": [],
                "datetime": [],
                "single_value": [],
                "unknown": []
            },
            "variables": output
        }
        
        with open(opath, 'w') as outfile:
            print(setting)
            json.dumps(setting, outfile, sort_keys=True, indent=4, separators=(',', ': '))
        
        return setting
             
"""
[
{'column': 'name', 'null': True, 'dtype': <dtype>, 'imputetype': <imputetype>}
]
"""

jcc = JSONCreateConfig('/Users/daniellee/Jupyter/utils/test_data/dice/05/01/*Realtimesuccess.json.gz')
tempoutput=jcc.generate('/Users/daniellee/Jupyter/utils/test_data/dice_config.json')
# Out:
# {'setting': {'continuous': [], 'categorical': [], 'binary': [], 'datetime': [], 'single_value': [], 'unknown': []}, 'variables': [{'field': 'applies_to_1st_party', 'imputetype': 'categorical', 'dtype': 'category', 'null': True}, {'field': 'applies_to_3rd_party', 'imputetype': 'categorical', 'dtype': 'category', 'null': True}, {'field': 'bare_handle_emailaddress', 'imputetype': 'categorical', 'dtype': 'category', 'null': True}, {'field': 'bare_handle_emailaddress_eid', 'imputetype': 'categorical', 'dtype': 'category', 'null': True}, {'field': 'bare_handle_emailaddress_num_bad_user_per_bare_handle_email_lifetime', 'imputetype': 'categorical', 'dtype': 'category', 'null': True}, {'field': 'bare_handle_emailaddress_num_user_per_bare_handle_email_lifetime', 'imputetype': 'categorical', 'dtype': 'category', 'null': True}, {'field': 'bare_handle_emailaddress_sim_created_at', 'imputetype': 'datetime', 'dtype': 'datetime64[ns]', 'null': True}, {'field': 'bare_handle_emailaddress_sim_creation_date', 'imputetype': 'datetime', 'dtype': 'object', 'null': True}, {'field': 'bare_handle_emailaddress_sim_frequently_used', 'imputetype': 'binary', 'dtype': 'float64', 'null': True}, {'field': 'bare_handle_emailaddress_sim_updated_at', 'imputetype': 'datetime', 'dtype': 'datetime64[ns]', 'null': True}, {'field': 'bare_handle_emailaddress_sim_updated_customer', 'imputetype': 'single_value', 'dtype': 'float64', 'null': True}, {'field': 'bare_handle_emailaddress_sim_updated_internal', 'imputetype': 'single_value', 'dtype': 'float64', 'null': True}, {'field': 'city', 'imputetype': 'categorical', 'dtype': 'category', 'null': True}, {'field': 'country', 'imputetype': 'categorical', 'dtype': 'category', 'null': True}, {'field': 'customer_session_id', 'imputetype': 'categorical', 'dtype': 'category', 'null': True}, {'field': 'date', 'imputetype': 'datetime', 'dtype': 'datetime64[ns]', 'null': False}, {'field': 'device_browser_family', 'imputetype': 'categorical', 'dtype': 'category', 'null': True}, {'field': 'device_customer_user_id', 'imputetype': 'categorical', 'dtype': 'category', 'null': True}, {'field': 'device_id', 'imputetype': 'unknown', 'dtype': 'object', 'null': True}, {'field': 'device_id_eid', 'imputetype': 'unknown', 'dtype': 'object', 'null': True}, {'field': 'device_id_ip', 'imputetype': 'categorical', 'dtype': 'category', 'null': True}, {'field': 'device_id_ip_city', 'imputetype': 'categorical', 'dtype': 'category', 'null': True}, {'field': 'device_id_ip_country', 'imputetype': 'categorical', 'dtype': 'category', 'null': True}, {'field': 'device_id_ip_eid', 'imputetype': 'categorical', 'dtype': 'category', 'null': True}, {'field': 'device_id_ip_ews_accuracy_radius', 'imputetype': 'categorical', 'dtype': 'category', 'null': True}, {'field': 'device_id_ip_ews_autonomous_system_number', 'imputetype': 'categorical', 'dtype': 'category', 'null': True}, {'field': 'device_id_ip_ews_autonomous_system_organization', 'imputetype': 'categorical', 'dtype': 'category', 'null': True}, {'field': 'device_id_ip_ews_city_name', 'imputetype': 'categorical', 'dtype': 'category', 'null': True}, {'field': 'device_id_ip_ews_connection_type', 'imputetype': 'categorical', 'dtype': 'category', 'null': True}, {'field': 'device_id_ip_ews_continent_name', 'imputetype': 'categorical', 'dtype': 'category', 'null': True}, {'field': 'device_id_ip_ews_country_iso_code', 'imputetype': 'categorical', 'dtype': 'category', 'null': True}, {'field': 'device_id_ip_ews_country_name', 'imputetype': 'categorical', 'dtype': 'category', 'null': True}, {'field': 'device_id_ip_ews_domain', 'imputetype': 'categorical', 'dtype': 'category', 'null': True}, {'field': 'device_id_ip_ews_geo_error', 'imputetype': 'binary', 'dtype': 'object', 'null': True}, {'field': 'device_id_ip_ews_is_anonymous_proxy', 'imputetype': 'binary', 'dtype': 'float64', 'null': True}, {'field': 'device_id_ip_ews_is_satellite_provider', 'imputetype': 'binary', 'dtype': 'float64', 'null': True}, {'field': 'device_id_i ...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-443-0fa8c246de2c> in <module>()
#     243
#     244 jcc = JSONCreateConfig('/Users/daniellee/Jupyter/utils/test_data/dice/05/01/*Realtimesuccess.json.gz')
# --> 245 tempoutput=jcc.generate('/Users/daniellee/Jupyter/utils/test_data/dice_config.json')
#
# <ipython-input-443-0fa8c246de2c> in generate(self, opath, pfile, id_vars)
#     232         with open(opath, 'w') as outfile:
#     233             print(setting)
# --> 234             json.dumps(setting, outfile, sort_keys=True, indent=4, separators=(',', ': '))
#     235
#     236         return setting
#
# TypeError: dumps() takes 1 positional argument but 2 positional arguments (and 3 keyword-only arguments) were given

# %%
o = '/Users/daniellee/Jupyter/utils/test_data/dice_config.json'
with open(o, 'w') as outfile:
    json.dumps(setting, outfile, sort_keys=True, indent=4, separators=(',', ': '))
# Out:
# {'setting': {'binary': [],
#   'categorical': [],
#   'continuous': [],
#   'datetime': [],
#   'single_value': [],
#   'unknown': []},
#  'variables': [{'dtype': 'category',
#    'field': 'applies_to_1st_party',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'applies_to_3rd_party',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'bare_handle_emailaddress',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'bare_handle_emailaddress_eid',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'bare_handle_emailaddress_num_bad_user_per_bare_handle_email_lifetime',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'bare_handle_emailaddress_num_user_per_bare_handle_email_lifetime',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'datetime64[ns]',
#    'field': 'bare_handle_emailaddress_sim_created_at',
#    'imputetype': 'datetime',
#    'null': True},
#   {'dtype': 'object',
#    'field': 'bare_handle_emailaddress_sim_creation_date',
#    'imputetype': 'datetime',
#    'null': True},
#   {'dtype': 'float64',
#    'field': 'bare_handle_emailaddress_sim_frequently_used',
#    'imputetype': 'binary',
#    'null': True},
#   {'dtype': 'datetime64[ns]',
#    'field': 'bare_handle_emailaddress_sim_updated_at',
#    'imputetype': 'datetime',
#    'null': True},
#   {'dtype': 'float64',
#    'field': 'bare_handle_emailaddress_sim_updated_customer',
#    'imputetype': 'single_value',
#    'null': True},
#   {'dtype': 'float64',
#    'field': 'bare_handle_emailaddress_sim_updated_internal',
#    'imputetype': 'single_value',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'city',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'country',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'customer_session_id',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'datetime64[ns]',
#    'field': 'date',
#    'imputetype': 'datetime',
#    'null': False},
#   {'dtype': 'category',
#    'field': 'device_browser_family',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_customer_user_id',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'object',
#    'field': 'device_id',
#    'imputetype': 'unknown',
#    'null': True},
#   {'dtype': 'object',
#    'field': 'device_id_eid',
#    'imputetype': 'unknown',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_ip',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_ip_city',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_ip_country',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_ip_eid',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_ip_ews_accuracy_radius',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_ip_ews_autonomous_system_number',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_ip_ews_autonomous_system_organization',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_ip_ews_city_name',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_ip_ews_connection_type',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_ip_ews_continent_name',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_ip_ews_country_iso_code',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_ip_ews_country_name',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_ip_ews_domain',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'object',
#    'field': 'device_id_ip_ews_geo_error',
#    'imputetype': 'binary',
#    'null': True},
#   {'dtype': 'float64',
#    'field': 'device_id_ip_ews_is_anonymous_proxy',
#    'imputetype': 'binary',
#    'null': True},
#   {'dtype': 'float64',
#    'field': 'device_id_ip_ews_is_satellite_provider',
#    'imputetype': 'binary',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_ip_ews_isp',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'float64',
#    'field': 'device_id_ip_ews_latitutde',
#    'imputetype': 'continuous',
#    'null': True},
#   {'dtype': 'float64',
#    'field': 'device_id_ip_ews_longitude',
#    'imputetype': 'continuous',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_ip_ews_organization',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_ip_ews_postal_code',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_ip_ews_registered_country_iso_code',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_ip_ews_registered_country_name',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_ip_ews_subdivisions_name',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_ip_ews_time_zone',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_ip_isp',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_ip_num_bad_iuser_per_ip_lifetime',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_ip_num_bad_user_per_ip_1day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_ip_num_bad_user_per_ip_30day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_ip_num_bad_user_per_ip_7day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_ip_num_bad_user_per_ip_90day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_ip_num_bad_user_per_ip_lifetime',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_ip_num_distinct_deviceid_per_ip_1day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_ip_num_distinct_deviceid_per_ip_30day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_ip_num_distinct_deviceid_per_ip_7day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_ip_num_distinct_deviceid_per_ip_90day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_ip_num_distinct_emaildomain_per_ip_1day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_ip_num_distinct_emaildomain_per_ip_30day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_ip_num_distinct_emaildomain_per_ip_7day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_ip_num_distinct_emaildomain_per_ip_90day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_ip_num_distinct_jauser_per_jaip_1day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_ip_num_distinct_jauser_per_jaip_30day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_ip_num_distinct_jauser_per_jaip_7day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_ip_num_distinct_job_application_per_jaip_30day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_ip_num_distinct_job_application_per_jaip_7day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_ip_num_distinct_user_per_ip_1day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_ip_num_distinct_user_per_ip_30day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_ip_num_distinct_user_per_ip_7day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_ip_num_distinct_user_per_ip_90day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_ip_num_distinct_username_per_ip_1day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_ip_num_distinct_username_per_ip_30day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_ip_num_distinct_username_per_ip_7day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_ip_num_distinct_username_per_ip_90day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_ip_num_user_per_ip_lifetime',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'float64',
#    'field': 'device_id_ip_numdays_between_user_firstseen_lastseen_by_ip',
#    'imputetype': 'continuous',
#    'null': True},
#   {'dtype': 'float64',
#    'field': 'device_id_ip_numdays_since_user_firstseen_by_ip',
#    'imputetype': 'continuous',
#    'null': True},
#   {'dtype': 'float64',
#    'field': 'device_id_ip_numdays_since_user_lastseen_by_ip',
#    'imputetype': 'continuous',
#    'null': True},
#   {'dtype': 'float64',
#    'field': 'device_id_ip_proxy',
#    'imputetype': 'binary',
#    'null': True},
#   {'dtype': 'float64',
#    'field': 'device_id_ip_sim_bl',
#    'imputetype': 'single_value',
#    'null': True},
#   {'dtype': 'datetime64[ns]',
#    'field': 'device_id_ip_sim_created_at',
#    'imputetype': 'datetime',
#    'null': True},
#   {'dtype': 'object',
#    'field': 'device_id_ip_sim_creation_date',
#    'imputetype': 'datetime',
#    'null': True},
#   {'dtype': 'object',
#    'field': 'device_id_ip_sim_dc',
#    'imputetype': 'binary',
#    'null': True},
#   {'dtype': 'float64',
#    'field': 'device_id_ip_sim_frequently_used',
#    'imputetype': 'binary',
#    'null': True},
#   {'dtype': 'datetime64[ns]',
#    'field': 'device_id_ip_sim_updated_at',
#    'imputetype': 'datetime',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_ip_sim_updated_customer',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_ip_sim_updated_internal',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'float64',
#    'field': 'device_id_ip_ts_user_firstseen_by_ip_lifetime',
#    'imputetype': 'continuous',
#    'null': True},
#   {'dtype': 'float64',
#    'field': 'device_id_ip_ts_user_lastseen_by_ip_lifetime',
#    'imputetype': 'continuous',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_ip_user_badnessratio_per_ip_1day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_ip_user_badnessratio_per_ip_30day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_ip_user_badnessratio_per_ip_7day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_ip_user_badnessratio_per_ip_90day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'float64',
#    'field': 'device_id_latitude',
#    'imputetype': 'continuous',
#    'null': True},
#   {'dtype': 'float64',
#    'field': 'device_id_longitude',
#    'imputetype': 'continuous',
#    'null': True},
#   {'dtype': 'float64',
#    'field': 'device_id_num_bad_iuser_per_deviceid_lifetime',
#    'imputetype': 'binary',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_num_bad_user_per_deviceid_1day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_num_bad_user_per_deviceid_30day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_num_bad_user_per_deviceid_7day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_num_bad_user_per_deviceid_90day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_num_bad_user_per_deviceid_lifetime',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_num_distinct_ab_per_deviceid_1day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_num_distinct_ab_per_deviceid_30day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_num_distinct_ab_per_deviceid_7day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_num_distinct_ed_per_deviceid_30day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_num_distinct_emaildomain_per_deviceid_1day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_num_distinct_emaildomain_per_deviceid_30day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_num_distinct_emaildomain_per_deviceid_7day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_num_distinct_emaildomain_per_deviceid_90day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_num_distinct_ep_per_deviceid_1day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_num_distinct_ep_per_deviceid_30day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_num_distinct_ep_per_deviceid_7day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_num_distinct_ip_per_deviceid_1day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_num_distinct_ip_per_deviceid_30day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_num_distinct_ip_per_deviceid_7day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_num_distinct_ip_per_deviceid_90day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_num_distinct_jauser_per_jadeviceid_1day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_num_distinct_jauser_per_jadeviceid_7day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_num_distinct_jauser_per_jadeviceid_90day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_num_distinct_job_application_per_jadeviceid_30day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_num_distinct_job_application_per_jadeviceid_90day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_num_distinct_user_per_deviceid_1day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_num_distinct_user_per_deviceid_30day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_num_distinct_user_per_deviceid_7day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_num_distinct_user_per_deviceid_90day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_num_distinct_username_per_deviceid_1day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_num_distinct_username_per_deviceid_30day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_num_distinct_username_per_deviceid_7day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_num_distinct_username_per_deviceid_90day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_num_user_per_deviceid_lifetime',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'float64',
#    'field': 'device_id_sim_bl',
#    'imputetype': 'single_value',
#    'null': True},
#   {'dtype': 'datetime64[ns]',
#    'field': 'device_id_sim_created_at',
#    'imputetype': 'datetime',
#    'null': True},
#   {'dtype': 'object',
#    'field': 'device_id_sim_creation_date',
#    'imputetype': 'datetime',
#    'null': True},
#   {'dtype': 'float64',
#    'field': 'device_id_sim_frequently_used',
#    'imputetype': 'binary',
#    'null': True},
#   {'dtype': 'datetime64[ns]',
#    'field': 'device_id_sim_updated_at',
#    'imputetype': 'datetime',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_sim_updated_customer',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'float64',
#    'field': 'device_id_sim_updated_internal',
#    'imputetype': 'binary',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_user_badnessratio_per_deviceid_1day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_user_badnessratio_per_deviceid_30day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_user_badnessratio_per_deviceid_7day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_user_badnessratio_per_deviceid_90day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_variability_username_to_deviceid_1day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_variability_username_to_deviceid_30day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_id_variability_username_to_deviceid_7day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_language',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_ml_score',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'device_os_family',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'object',
#    'field': 'device_session_id',
#    'imputetype': 'unknown',
#    'null': True},
#   {'dtype': 'object',
#    'field': 'device_signals_eid',
#    'imputetype': 'unknown',
#    'null': True},
#   {'dtype': 'float64',
#    'field': 'ds_agency',
#    'imputetype': 'binary',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'ds_tax_term',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'ds_work_authorization',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'object', 'field': 'eid', 'imputetype': 'unknown', 'null': False},
#   {'dtype': 'category',
#    'field': 'email_domain',
#    'imputetype': 'categorical',
#    'null': False},
#   {'dtype': 'int64',
#    'field': 'email_length',
#    'imputetype': 'unknown',
#    'null': False},
#   {'dtype': 'float64',
#    'field': 'email_matches_username',
#    'imputetype': 'binary',
#    'null': True},
#   {'dtype': 'object',
#    'field': 'emailaddress',
#    'imputetype': 'unknown',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'first_name',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'first_profile_date',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'object',
#    'field': 'full_name',
#    'imputetype': 'unknown',
#    'null': True},
#   {'dtype': 'object',
#    'field': 'full_name_concat',
#    'imputetype': 'unknown',
#    'null': True},
#   {'dtype': 'object',
#    'field': 'full_name_eid',
#    'imputetype': 'unknown',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'full_name_num_distinct_deviceid_per_username_1day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'full_name_num_distinct_deviceid_per_username_30day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'full_name_num_distinct_deviceid_per_username_7day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'full_name_num_distinct_deviceid_per_username_90day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'full_name_num_distinct_user_per_username',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'full_name_num_distinct_user_per_username_1day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'full_name_num_distinct_user_per_username_30day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'full_name_num_distinct_user_per_username_7day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'full_name_num_distinct_user_per_username_90day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'datetime64[ns]',
#    'field': 'full_name_sim_created_at',
#    'imputetype': 'datetime',
#    'null': True},
#   {'dtype': 'object',
#    'field': 'full_name_sim_creation_date',
#    'imputetype': 'datetime',
#    'null': True},
#   {'dtype': 'float64',
#    'field': 'full_name_sim_frequently_used',
#    'imputetype': 'binary',
#    'null': True},
#   {'dtype': 'datetime64[ns]',
#    'field': 'full_name_sim_updated_at',
#    'imputetype': 'datetime',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'full_name_sim_updated_customer',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'full_name_sim_updated_internal',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'float64',
#    'field': 'full_name_username_kbdistance',
#    'imputetype': 'continuous',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'full_name_username_length',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'full_name_username_nonalpharatio',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'full_name_username_repeatratio',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'full_name_username_vowelratio',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'full_name_variability_deviceid_to_username_1day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'full_name_variability_deviceid_to_username_30day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'full_name_variability_deviceid_to_username_7day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'groupid',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'float64',
#    'field': 'handle_kbdistance',
#    'imputetype': 'continuous',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'handle_nonalpharatio',
#    'imputetype': 'categorical',
#    'null': False},
#   {'dtype': 'int64',
#    'field': 'handle_repeatratio',
#    'imputetype': 'single_value',
#    'null': False},
#   {'dtype': 'category',
#    'field': 'handle_vowelratio',
#    'imputetype': 'categorical',
#    'null': False},
#   {'dtype': 'int64',
#    'field': 'is_fraud',
#    'imputetype': 'binary',
#    'null': False},
#   {'dtype': 'category',
#    'field': 'jobid',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'last_activity_date',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'object',
#    'field': 'last_name',
#    'imputetype': 'unknown',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'lastname_length',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'object',
#    'field': 'normalized_email',
#    'imputetype': 'unknown',
#    'null': False},
#   {'dtype': 'category',
#    'field': 'num_distinct_ab_per_user_1day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'num_distinct_ab_per_user_30day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'num_distinct_ab_per_user_7day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'num_distinct_appdeviceid_per_appuser_1day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'num_distinct_appdeviceid_per_appuser_30day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'num_distinct_appdeviceid_per_appuser_7day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'num_distinct_ed_per_user_1day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'num_distinct_ed_per_user_30day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'num_distinct_ed_per_user_7day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'num_distinct_ep_per_user_1day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'num_distinct_ep_per_user_30day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'num_distinct_ep_per_user_7day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'num_distinct_jadeviceid_per_jauser_1day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'num_distinct_jadeviceid_per_jauser_30day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'num_distinct_jadeviceid_per_jauser_7day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'num_distinct_jaip_per_jauser_1day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'num_distinct_jaip_per_jauser_30day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'num_distinct_jaip_per_jauser_7day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'num_distinct_job_application_per_jauser_1day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'num_distinct_job_application_per_jauser_30day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'num_distinct_job_application_per_jauser_7day',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'int64',
#    'field': 'num_email_dups',
#    'imputetype': 'unknown',
#    'null': False},
#   {'dtype': 'object',
#    'field': 'sim_audit_source',
#    'imputetype': 'single_value',
#    'null': False},
#   {'dtype': 'float64',
#    'field': 'sim_bl',
#    'imputetype': 'single_value',
#    'null': True},
#   {'dtype': 'datetime64[ns]',
#    'field': 'sim_created_at',
#    'imputetype': 'datetime',
#    'null': False},
#   {'dtype': 'object',
#    'field': 'sim_creation_date',
#    'imputetype': 'datetime',
#    'null': False},
#   {'dtype': 'object', 'field': 'sim_dc', 'imputetype': 'binary', 'null': True},
#   {'dtype': 'float64',
#    'field': 'sim_dc_reasons',
#    'imputetype': 'single_value',
#    'null': True},
#   {'dtype': 'float64',
#    'field': 'sim_frequently_used',
#    'imputetype': 'binary',
#    'null': True},
#   {'dtype': 'float64',
#    'field': 'sim_is_fraud',
#    'imputetype': 'single_value',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'sim_ladt',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'sim_ll',
#    'imputetype': 'categorical',
#    'null': False},
#   {'dtype': 'float64',
#    'field': 'sim_ll_10PlusUsersPerDevice',
#    'imputetype': 'binary',
#    'null': True},
#   {'dtype': 'float64',
#    'field': 'sim_ll_25PlusUsersPerDevice',
#    'imputetype': 'binary',
#    'null': True},
#   {'dtype': 'float64',
#    'field': 'sim_ll_BlackListEmailDomains',
#    'imputetype': 'binary',
#    'null': True},
#   {'dtype': 'float64',
#    'field': 'sim_ll_BlacklistedIP',
#    'imputetype': 'binary',
#    'null': True},
#   {'dtype': 'float64',
#    'field': 'sim_ll_DomainisDice',
#    'imputetype': 'binary',
#    'null': True},
#   {'dtype': 'float64',
#    'field': 'sim_ll_EmailContainsBadWords',
#    'imputetype': 'binary',
#    'null': True},
#   {'dtype': 'float64',
#    'field': 'sim_ll_EmailmatchesUsername',
#    'imputetype': 'binary',
#    'null': True},
#   {'dtype': 'float64',
#    'field': 'sim_ll_EmployerEmployeeFromSameDevice',
#    'imputetype': 'binary',
#    'null': True},
#   {'dtype': 'float64',
#    'field': 'sim_ll_EwsCountryCodeisIndia',
#    'imputetype': 'binary',
#    'null': True},
#   {'dtype': 'float64',
#    'field': 'sim_ll_HighApplicationsPerDevice',
#    'imputetype': 'binary',
#    'null': True},
#   {'dtype': 'float64',
#    'field': 'sim_ll_HighApplicationsPerIP',
#    'imputetype': 'binary',
#    'null': True},
#   {'dtype': 'float64',
#    'field': 'sim_ll_HighDevicePerUser_1_day_JA',
#    'imputetype': 'binary',
#    'null': True},
#   {'dtype': 'float64',
#    'field': 'sim_ll_HighDevicePerUser_JA',
#    'imputetype': 'binary',
#    'null': True},
#   {'dtype': 'float64',
#    'field': 'sim_ll_HighEmailDups',
#    'imputetype': 'binary',
#    'null': True},
#   {'dtype': 'float64',
#    'field': 'sim_ll_HighUserPerUsername',
#    'imputetype': 'binary',
#    'null': True},
#   {'dtype': 'float64',
#    'field': 'sim_ll_HighUserperBareHandleEmail',
#    'imputetype': 'binary',
#    'null': True},
#   {'dtype': 'float64',
#    'field': 'sim_ll_HighUsersAndApplicationsPerDevice',
#    'imputetype': 'binary',
#    'null': True},
#   {'dtype': 'float64',
#    'field': 'sim_ll_IPcountryIsIndia',
#    'imputetype': 'binary',
#    'null': True},
#   {'dtype': 'float64',
#    'field': 'sim_ll_IPcountryIsIndia_JA',
#    'imputetype': 'binary',
#    'null': True},
#   {'dtype': 'float64',
#    'field': 'sim_ll_LastnameIsOneLetter',
#    'imputetype': 'binary',
#    'null': True},
#   {'dtype': 'float64',
#    'field': 'sim_ll_Mobileapp_User',
#    'imputetype': 'binary',
#    'null': True},
#   {'dtype': 'float64',
#    'field': 'sim_ll_MultipleApplicationsPerIPLast1Day',
#    'imputetype': 'binary',
#    'null': True},
#   {'dtype': 'float64',
#    'field': 'sim_ll_MultipleDevicesPerIP_JA',
#    'imputetype': 'binary',
#    'null': True},
#   {'dtype': 'float64',
#    'field': 'sim_ll_MultipleDevicesPerIp',
#    'imputetype': 'binary',
#    'null': True},
#   {'dtype': 'float64',
#    'field': 'sim_ll_MultipleJobApplicationUsersPerDevice',
#    'imputetype': 'binary',
#    'null': True},
#   {'dtype': 'float64',
#    'field': 'sim_ll_MultipleJobApplicationUsersPerIP',
#    'imputetype': 'binary',
#    'null': True},
#   {'dtype': 'float64',
#    'field': 'sim_ll_MultipleUsersPerDeviceLast1Day',
#    'imputetype': 'binary',
#    'null': True},
#   {'dtype': 'float64',
#    'field': 'sim_ll_NameContainsBadWords',
#    'imputetype': 'binary',
#    'null': True},
#   {'dtype': 'float64',
#    'field': 'sim_ll_RuleBrianThornton',
#    'imputetype': 'binary',
#    'null': True},
#   {'dtype': 'float64',
#    'field': 'sim_ll_TooManyDotsinEmailID',
#    'imputetype': 'binary',
#    'null': True},
#   {'dtype': 'float64',
#    'field': 'sim_ll_UserFromKnownBadDevices',
#    'imputetype': 'binary',
#    'null': True},
#   {'dtype': 'float64',
#    'field': 'sim_ll_UserFromKnownBadIP',
#    'imputetype': 'binary',
#    'null': True},
#   {'dtype': 'float64',
#    'field': 'sim_ll_VeryHighDevicePerUser_1_day_JA',
#    'imputetype': 'binary',
#    'null': True},
#   {'dtype': 'float64',
#    'field': 'sim_ll_VeryHighDevicePerUser_1day_JA',
#    'imputetype': 'binary',
#    'null': True},
#   {'dtype': 'float64',
#    'field': 'sim_ll_WhitelistedDiceIP',
#    'imputetype': 'binary',
#    'null': True},
#   {'dtype': 'float64',
#    'field': 'sim_ll_countrymatchesIPcountry',
#    'imputetype': 'binary',
#    'null': True},
#   {'dtype': 'float64',
#    'field': 'sim_local_feedback_status',
#    'imputetype': 'single_value',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'sim_pipeline_triggered_by_entity',
#    'imputetype': 'categorical',
#    'null': False},
#   {'dtype': 'object',
#    'field': 'sim_pipeline_triggered_reason',
#    'imputetype': 'binary',
#    'null': False},
#   {'dtype': 'category',
#    'field': 'sim_ps',
#    'imputetype': 'categorical',
#    'null': False},
#   {'dtype': 'object',
#    'field': 'sim_ps1',
#    'imputetype': 'single_value',
#    'null': False},
#   {'dtype': 'category',
#    'field': 'sim_q',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'sim_qadtr',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'sim_qnote',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'sim_queues',
#    'imputetype': 'categorical',
#    'null': False},
#   {'dtype': 'int64',
#    'field': 'sim_sc',
#    'imputetype': 'unknown',
#    'null': False},
#   {'dtype': 'float64',
#    'field': 'sim_sc_ml',
#    'imputetype': 'single_value',
#    'null': True},
#   {'dtype': 'datetime64[ns]',
#    'field': 'sim_updated_at',
#    'imputetype': 'datetime',
#    'null': False},
#   {'dtype': 'float64',
#    'field': 'sim_updated_customer',
#    'imputetype': 'continuous',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'sim_updated_internal',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'object',
#    'field': 'sim_wl',
#    'imputetype': 'binary',
#    'null': False},
#   {'dtype': 'object',
#    'field': 'sim_wl2',
#    'imputetype': 'binary',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'state',
#    'imputetype': 'categorical',
#    'null': True},
#   {'dtype': 'float64',
#    'field': 'third_party',
#    'imputetype': 'binary',
#    'null': True},
#   {'dtype': 'category',
#    'field': 'type',
#    'imputetype': 'categorical',
#    'null': True}]}

# %%
jcc2 = JSONCreateConfig('/Users/daniellee/Jupyter/utils/test_data/home_advisor/*Realtimesuccess.json.gz')
tempoutput2=jcc2.generate()
# Out:
# 2
# ['/Users/daniellee/Jupyter/utils/test_data/home_advisor/2018-05-07T18H-Realtimesuccess.json.gz'
#  '/Users/daniellee/Jupyter/utils/test_data/home_advisor/2018-05-07T19H-Realtimesuccess.json.gz']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-425-5ca4a5321fe2> in <module>()
#       1 jcc2 = JSONCreateConfig('/Users/daniellee/Jupyter/utils/test_data/home_advisor/*Realtimesuccess.json.gz')
# ----> 2 tempoutput2=jcc2.generate()
#
# <ipython-input-424-7cec10f5e157> in generate(self, opath, pfile, id_vars)
#     207                                       replace=False)
#     208         print(files_to_select)
# --> 209         cols, itypes, dtypes, nulls = self.multiple_file_process(files_to_select)
#     210
#     211         output = list()
#
# <ipython-input-424-7cec10f5e157> in multiple_file_process(self, path)
#     171         """
#     172
# --> 173         sample = self.read_multiple_json(path)
#     174         columns = sample.columns
#     175         dtypes = sample.dtypes.to_dict()
#
# <ipython-input-424-7cec10f5e157> in read_multiple_json(self, paths)
#     161         def read_json(path):
#     162             return pd.read_json(path, lines=True)
# --> 163         return pd.concat(map(read_json, paths))
#     164
#     165     def multiple_file_process(self, path):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, copy)
#     210                        keys=keys, levels=levels, names=names,
#     211                        verify_integrity=verify_integrity,
# --> 212                        copy=copy)
#     213     return op.get_result()
#     214
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, join_axes, keys, levels, names, ignore_index, verify_integrity, copy)
#     240             objs = [objs[k] for k in keys]
#     241         else:
# --> 242             objs = list(objs)
#     243
#     244         if len(objs) == 0:
#
# <ipython-input-424-7cec10f5e157> in read_json(path)
#     160     def read_multiple_json(self, paths):
#     161         def read_json(path):
# --> 162             return pd.read_json(path, lines=True)
#     163         return pd.concat(map(read_json, paths))
#     164
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/json/json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
#     364         return json_reader
#     365
# --> 366     return json_reader.read()
#     367
#     368
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/json/json.py in read(self)
#     462             data = to_str(self.data)
#     463             obj = self._get_object_parser(
# --> 464                 self._combine_lines(data.split('\n'))
#     465             )
#     466         else:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/json/json.py in _get_object_parser(self, json)
#     482         obj = None
#     483         if typ == 'frame':
# --> 484             obj = FrameParser(json, **kwargs).parse()
#     485
#     486         if typ == 'series' or obj is None:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/json/json.py in parse(self)
#     574
#     575         else:
# --> 576             self._parse_no_numpy()
#     577
#     578         if self.obj is None:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/json/json.py in _parse_no_numpy(self)
#     791         if orient == "columns":
#     792             self.obj = DataFrame(
# --> 793                 loads(json, precise_float=self.precise_float), dtype=None)
#     794         elif orient == "split":
#     795             decoded = dict((str(k), v)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     367                     if is_named_tuple(data[0]) and columns is None:
#     368                         columns = data[0]._fields
# --> 369                     arrays, columns = _to_arrays(data, columns, dtype=dtype)
#     370                     columns = _ensure_index(columns)
#     371
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _to_arrays(data, columns, coerce_float, dtype)
#    6285     elif isinstance(data[0], collections.Mapping):
#    6286         return _list_of_dict_to_arrays(data, columns,
# -> 6287                                        coerce_float=coerce_float, dtype=dtype)
#    6288     elif isinstance(data[0], Series):
#    6289         return _list_of_series_to_arrays(data, columns,
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _list_of_dict_to_arrays(data, columns, coerce_float, dtype)
#    6400         gen = (list(x.keys()) for x in data)
#    6401         sort = not any(isinstance(d, OrderedDict) for d in data)
# -> 6402         columns = lib.fast_unique_multiple_list_gen(gen, sort=sort)
#    6403
#    6404     # assure that they are of the base dict class and not of derived
#
# pandas/_libs/lib.pyx in pandas._libs.lib.fast_unique_multiple_list_gen()
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in <genexpr>(.0)
#    6398 def _list_of_dict_to_arrays(data, columns, coerce_float=False, dtype=None):
#    6399     if columns is None:
# -> 6400         gen = (list(x.keys()) for x in data)
#    6401         sort = not any(isinstance(d, OrderedDict) for d in data)
#    6402         columns = lib.fast_unique_multiple_list_gen(gen, sort=sort)
#
# KeyboardInterrupt:

# %%
import glob
def read_json(x):
    return pd.read_json(x, lines=True)

df_json = pd.concat(map(read_json, glob.glob('/Users/daniellee/Jupyter/utils/test_data/dice/05/01/*Realtimesuccess.json.gz')))

# %%
df_json_dtypes = df_json.dtypes.to_dict()

# %%
df_json['device_id_ip_ews_country_iso_code'] = df_json['device_id_ip_ews_country_iso_code'].astype('category')

# %%
df_json.dtypes == 'datetime64[ns]'
# Out:
# applies_to_1st_party                                                    False
# applies_to_3rd_party                                                    False
# bare_handle_emailaddress                                                False
# bare_handle_emailaddress_eid                                            False
# bare_handle_emailaddress_num_bad_user_per_bare_handle_email_lifetime    False
# bare_handle_emailaddress_num_user_per_bare_handle_email_lifetime        False
# bare_handle_emailaddress_sim_created_at                                  True
# bare_handle_emailaddress_sim_creation_date                              False
# bare_handle_emailaddress_sim_frequently_used                            False
# bare_handle_emailaddress_sim_updated_at                                  True
# bare_handle_emailaddress_sim_updated_customer                           False
# bare_handle_emailaddress_sim_updated_internal                           False
# city                                                                    False
# country                                                                 False
# customer_session_id                                                     False
# date                                                                     True
# device_browser_family                                                   False
# device_customer_user_id                                                 False
# device_id                                                               False
# device_id_eid                                                           False
# device_id_ip                                                            False
# device_id_ip_city                                                       False
# device_id_ip_country                                                    False
# device_id_ip_eid                                                        False
# device_id_ip_ews_accuracy_radius                                        False
# device_id_ip_ews_autonomous_system_number                               False
# device_id_ip_ews_autonomous_system_organization                         False
# device_id_ip_ews_city_name                                              False
# device_id_ip_ews_connection_type                                        False
# device_id_ip_ews_continent_name                                         False
#                                                                         ...
# sim_ll_MultipleUsersPerDeviceLast1Day                                   False
# sim_ll_NameContainsBadWords                                             False
# sim_ll_Over30ApplicationsPerUserLast1Day                                False
# sim_ll_RuleBrianThornton                                                False
# sim_ll_TooManyDotsinEmailID                                             False
# sim_ll_UserFromKnownBadDevices                                          False
# sim_ll_UserFromKnownBadIP                                               False
# sim_ll_VeryHighDevicePerUser_1_day_JA                                   False
# sim_ll_VeryHighDevicePerUser_1day_JA                                    False
# sim_ll_WhitelistedDiceIP                                                False
# sim_ll_countrymatchesIPcountry                                          False
# sim_local_feedback_status                                               False
# sim_pipeline_triggered_by_entity                                        False
# sim_pipeline_triggered_reason                                           False
# sim_ps                                                                  False
# sim_ps1                                                                 False
# sim_q                                                                   False
# sim_qadtr                                                               False
# sim_qnote                                                               False
# sim_queues                                                              False
# sim_sc                                                                  False
# sim_sc_ml                                                               False
# sim_updated_at                                                           True
# sim_updated_customer                                                    False
# sim_updated_internal                                                    False
# sim_wl                                                                  False
# sim_wl2                                                                 False
# state                                                                   False
# third_party                                                             False
# type                                                                    False
# Length: 288, dtype: bool

# %%
readfile = DaskReadFile()
data2 = readfile.read_csv('/Users/daniellee/Data/device_risk_score/data_v1/raw/raw.csv', dtype=dtype)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-84-d5a86cda9483> in <module>()
#       1 readfile = DaskReadFile()
# ----> 2 data2 = readfile.read_csv('/Users/daniellee/Data/device_risk_score/data_v1/raw/raw.csv', dtype=dtype)
#
# TypeError: read_csv() got an unexpected keyword argument 'dtype'

# %%
data2 = dd.read_csv('/Users/daniellee/Data/device_risk_score/data_v1/raw/raw.csv', dtype=dtype, assume_missing=True)

# %%
data2.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# TypeError: Cannot cast array from dtype('O') to dtype('float64') according to the rule 'safe'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-94-77bbe7b50a36> in <module>()
# ----> 1 data2.head()
#
# ~/anaconda3/lib/python3.6/site-packages/dask/dataframe/core.py in head(self, n, npartitions, compute)
#     844
#     845         if compute:
# --> 846             result = result.compute()
#     847         return result
#     848
#
# ~/anaconda3/lib/python3.6/site-packages/dask/base.py in compute(self, **kwargs)
#     133         dask.base.compute
#     134         """
# --> 135         (result,) = compute(self, traverse=False, **kwargs)
#     136         return result
#     137
#
# ~/anaconda3/lib/python3.6/site-packages/dask/base.py in compute(*args, **kwargs)
#     331     postcomputes = [a.__dask_postcompute__() if is_dask_collection(a)
#     332                     else (None, a) for a in args]
# --> 333     results = get(dsk, keys, **kwargs)
#     334     results_iter = iter(results)
#     335     return tuple(a if f is None else f(next(results_iter), *a)
#
# ~/anaconda3/lib/python3.6/site-packages/dask/threaded.py in get(dsk, result, cache, num_workers, **kwargs)
#      73     results = get_async(pool.apply_async, len(pool._pool), dsk, result,
#      74                         cache=cache, get_id=_thread_get_id,
# ---> 75                         pack_exception=pack_exception, **kwargs)
#      76
#      77     # Cleanup pools associated to dead threads
#
# ~/anaconda3/lib/python3.6/site-packages/dask/local.py in get_async(apply_async, num_workers, dsk, result, cache, get_id, rerun_exceptions_locally, pack_exception, raise_exception, callbacks, dumps, loads, **kwargs)
#     519                         _execute_task(task, data)  # Re-execute locally
#     520                     else:
# --> 521                         raise_exception(exc, tb)
#     522                 res, worker_id = loads(res_info)
#     523                 state['cache'][key] = res
#
# ~/anaconda3/lib/python3.6/site-packages/dask/compatibility.py in reraise(exc, tb)
#      65         if exc.__traceback__ is not tb:
#      66             raise exc.with_traceback(tb)
# ---> 67         raise exc
#      68
#      69 else:
#
# ~/anaconda3/lib/python3.6/site-packages/dask/local.py in execute_task(key, task_info, dumps, loads, get_id, pack_exception)
#     288     try:
#     289         task, data = loads(task_info)
# --> 290         result = _execute_task(task, data)
#     291         id = get_id()
#     292         result = dumps((result, id))
#
# ~/anaconda3/lib/python3.6/site-packages/dask/local.py in _execute_task(arg, cache, dsk)
#     269         func, args = arg[0], arg[1:]
#     270         args2 = [_execute_task(a, cache) for a in args]
# --> 271         return func(*args2)
#     272     elif not ishashable(arg):
#     273         return arg
#
# ~/anaconda3/lib/python3.6/site-packages/dask/compatibility.py in apply(func, args, kwargs)
#      46     def apply(func, args, kwargs=None):
#      47         if kwargs:
# ---> 48             return func(*args, **kwargs)
#      49         else:
#      50             return func(*args)
#
# ~/anaconda3/lib/python3.6/site-packages/dask/dataframe/io/csv.py in pandas_read_text(reader, b, header, kwargs, dtypes, columns, write_header, enforce)
#      67     bio.write(b)
#      68     bio.seek(0)
# ---> 69     df = reader(bio, **kwargs)
#      70     if dtypes:
#      71         coerce_dtypes(df, dtypes)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     707                     skip_blank_lines=skip_blank_lines)
#     708
# --> 709         return _read(filepath_or_buffer, kwds)
#     710
#     711     parser_f.__name__ = name
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     453
#     454     try:
# --> 455         data = parser.read(nrows)
#     456     finally:
#     457         parser.close()
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1067                 raise ValueError('skipfooter not supported for iteration')
#    1068
# -> 1069         ret = self._engine.read(nrows)
#    1070
#    1071         if self.options.get('as_recarray'):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1837     def read(self, nrows=None):
#    1838         try:
# -> 1839             data = self._reader.read(nrows)
#    1840         except StopIteration:
#    1841             if self._first_chunk:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_column_data()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# ValueError: could not convert string to float: 'MSM8974'

# %%
data2_csv = pd.read_csv('/Users/daniellee/Data/device_risk_score/data_v1/raw/raw.csv', nrows=10000)
# Out:
# /Users/daniellee/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (2,4,6,7,8,10,12,14,15,17,20,21,22,36,43,45,48,53,55,56,57,58,60,61,62,63,64,66,71,73,75,82,83,86,87,88,89,90,91,92,93,94,96,98,99,100,102,103,104,105,106,107,108,109,110,111,112,113,114,115,117,121,127,142,145,150,154,291,292,295,316,328,330,334,337,339,341,343,349,351,353,355,357,359,363,365,367,369,371,375,377,381,383,385,391,393,395,397,399,401,405,407,409,411,413,415,417,419,421,423,425,427,430,437,439,441,443,445,447,448,451,452,453,454,455,456,457,458,461,462,463,465,466,477,481,482,483,484,485,487,488,489,490,491,496,499,500,501,502,505,506,541,557,560,561,562,563,564,566,567,568,569,570,575,577,578,579,580,584) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
dtype = data2.dtypes.to_dict()

# %%
data2_csv.apply(lambda x: 'MSM8974' in x, axis=0).sum()
# Out:
# 0

# %%
data2.dtypes.unique()
# Out:
# array([dtype('O'), dtype('float64'), dtype('int64'), dtype('bool')],
#       dtype=object)
